# %%
#from twitter_preprocess import *
import csv
import argparse
import pandas as pd
import numpy as np
import re
import os
from collections import Counter
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import KFold
from sklearn.svm import SVC

TRAIN = '../data/train/training_data.csv'
train_data = pd.read_csv(TRAIN, index_col=1)
dev_data = pd.read_csv('../data/dev/development_data.csv', index_col=1)

# %%
# get unigram counts for data
def get_unigrams_splitBySpace():
    unigrams = Counter()
    tweets = train_data[['tweet']]
    for row_index, row in tweets.iterrows():
        #print(row['tweet'], type(row['tweet']))
        s = row['tweet'].split()
        #print("S : ",type(s), s)
        for word in s:
            #print(word, type(word), type(s))
            unigrams[word] += 1
    return unigrams

# %%
sp = get_unigrams_splitBySpace()
sp
# Out:
# Counter({'Kim': 19,
#          'K': 13,
#          'is': 2190,
#          'alright': 9,
#          'but': 998,
#          'honestly': 15,
#          'so': 859,
#          'many': 136,
#          'niggas': 449,
#          'been': 257,
#          'in': 2369,
#          'that': 2441,
#          "I'd": 81,
#          'rather': 54,
#          'not..': 1,
#          'And': 200,
#          'Miley': 10,
#          'got': 938,
#          'unfollowed': 7,
#          'bitch': 5294,
#          'just': 994,
#          'strange.': 1,
#          "I'm": 1208,
#          'mother': 32,
#          'fucken': 6,
#          'sexy.': 2,
#          'I': 5203,
#          'have': 767,
#          'no': 794,
#          'time': 270,
#          'to': 4187,
#          'be': 1870,
#          'a': 7232,
#          'retard.': 14,
#          'RT': 6023,
#          '@Booskerz:': 1,
#          '"@DailySexSupply:': 1,
#          'Girls': 20,
#          'fuck': 858,
#          'back': 284,
#          '&gt;&gt;&gt;': 3,
#          '&#128525;&#128525;': 9,
#          'http://t.co/pI064ylhF6"': 1,
#          '@iDocLyfe': 3,
#          'your': 1103,
#          'last': 131,
#          'one': 470,
#          'was': 893,
#          'trash': 695,
#          'here': 213,
#          'Think': 6,
#          "it's": 342,
#          'okay': 31,
#          'take': 210,
#          'my': 2468,
#          'property': 1,
#          'and': 2910,
#          'break': 51,
#          'it?': 8,
#          'Fuck': 169,
#          'you': 3872,
#          'Apologizing': 1,
#          'advance': 1,
#          'for': 1650,
#          'actions,': 1,
#          'thee': 3,
#          'biggest': 24,
#          'when': 760,
#          'studying': 2,
#          '&#128522;&#128299;': 1,
#          'She': 156,
#          'used': 61,
#          'wit': 275,
#          'A$AP,': 1,
#          'Too': 27,
#          'Shortsaid': 1,
#          'he': 594,
#          'know': 594,
#          'from': 422,
#          'way': 152,
#          '@elise_palmer': 3,
#          'sounds': 25,
#          'like': 2043,
#          'gypos': 1,
#          'me': 1787,
#          '-': 202,
#          'they': 933,
#          'do': 554,
#          'this': 1231,
#          'all': 951,
#          'the': 5242,
#          'where': 166,
#          'lived': 7,
#          'Quit': 13,
#          'blowing': 7,
#          'up': 1061,
#          'feed': 19,
#          'bitches.': 108,
#          'please': 64,
#          'tell': 221,
#          'subbin': 2,
#          'her,': 10,
#          'ik': 10,
#          'of': 1987,
#          'faggs': 1,
#          'on': 1864,
#          'with': 1447,
#          'those': 147,
#          'lames,': 1,
#          'shit': 770,
#          'blocked': 15,
#          'or': 509,
#          'would': 294,
#          'lol': 522,
#          'never': 298,
#          'lie': 37,
#          'cry': 35,
#          'die': 55,
#          'we': 450,
#          'gone': 134,
#          'love': 495,
#          'friends': 77,
#          'hoes': 1507,
#          'yellow': 174,
#          'sluts': 11,
#          'call': 219,
#          'them': 482,
#          'gold': 20,
#          '@ChiefKeef:': 6,
#          'You': 591,
#          'niggaz': 28,
#          'get': 1052,
#          'emotionaaaal,': 1,
#          'remind': 8,
#          'bitch!': 92,
#          '#tbt': 8,
#          'i': 691,
#          'took': 62,
#          'likkle': 1,
#          'monkey': 102,
#          'jimmys': 2,
#          'http://t.co/LIK3xpZ6eZ': 1,
#          '@MisterDimmadome': 1,
#          'spiked': 2,
#          'damned': 3,
#          'nailed': 1,
#          'her': 849,
#          'down': 221,
#          'pull': 53,
#          'up,': 33,
#          'eat': 167,
#          'pussy,': 38,
#          'dip': 4,
#          '@NotWorldStar:': 1,
#          'When': 272,
#          'drop': 43,
#          'person': 57,
#          "y'all": 210,
#          "don't": 998,
#          'end': 48,
#          'together': 36,
#          'http://t.co/lLViTXweMX': 1,
#          '@danwashburn:': 1,
#          'The': 397,
#          'Man': 51,
#          'Who': 55,
#          'Captured': 1,
#          'Muammar': 1,
#          'Gaddafi': 1,
#          'Was': 16,
#          'Wearing': 1,
#          'A': 250,
#          'Yankees': 98,
#          'Cap:': 1,
#          'http://t.co/7G70pOpW': 1,
#          'Yall': 42,
#          'Skip': 1,
#          'Bayless': 1,
#          'about': 714,
#          'slit': 20,
#          'his': 400,
#          'wrists': 2,
#          'over': 261,
#          'Romo!': 1,
#          'Lol': 154,
#          '@Chill__Nigga:': 1,
#          "can't": 391,
#          'twenties': 2,
#          'stressing': 4,
#          'who': 448,
#          'playin': 27,
#          'games.': 5,
#          'straight': 75,
#          '@_xxsarafina': 1,
#          'haha': 86,
#          'hoe': 1179,
#          'go': 425,
#          'hard': 86,
#          'rt': 19,
#          'Kevin': 8,
#          'hart': 1,
#          '4"8': 1,
#          '&#128075;': 12,
#          'hi-ho': 1,
#          'http://t.co/FiC4FnRutZ': 1,
#          '@itskingdee:': 2,
#          '@1inkkofrosess': 7,
#          'hoes!': 19,
#          'bigger': 20,
#          'problems': 27,
#          'cook': 17,
#          'at': 815,
#          'house': 72,
#          '@NYRKelsMads': 11,
#          '@DaniloNavarro85': 1,
#          'Hey': 31,
#          'fag,': 5,
#          'said': 297,
#          'aunts.': 1,
#          '*He*': 1,
#          'it': 1162,
#          'you.': 86,
#          '@OfficialKingDre:': 3,
#          'WTF': 7,
#          'did': 143,
#          'do?': 6,
#          '&#128514;&#128514;': 137,
#          'https://t.co/5BFuSp9bfn': 1,
#          '@Cajun_peach:': 1,
#          'Because': 21,
#          'humans': 3,
#          "aren't": 34,
#          'delicious': 2,
#          'ho': 74,
#          '@peta:': 1,
#          'Smarter': 1,
#          'than': 281,
#          'dogs': 15,
#          'AND': 14,
#          '3-year-old': 1,
#          'child.': 3,
#          'So': 158,
#          'why': 286,
#          'EAT': 2,
#          'them?': 3,
#          'http://t.co/eRT&#8230;': 1,
#          '"I': 96,
#          'will': 332,
#          'u': 885,
#          'stand".': 1,
#          '"U': 3,
#          'dizzy': 1,
#          'bitch".': 2,
#          'Two': 15,
#          'unique': 2,
#          '&amp;': 666,
#          'separate': 3,
#          'phrases': 1,
#          'overheard': 1,
#          'relative': 2,
#          'saying': 81,
#          'younger.': 2,
#          '&#8220;@MattieTrump97:': 1,
#          'Eat': 23,
#          'lot': 89,
#          'protein': 1,
#          'pussy': 1369,
#          '#MattieTrumpsTipsForABetterLife&#8221;': 1,
#          'whole': 57,
#          'ass': 1151,
#          'rebuild': 1,
#          'tranny,': 2,
#          'driving': 14,
#          'its': 174,
#          '4': 68,
#          'years': 55,
#          'till': 39,
#          'finally': 19,
#          'goes': 37,
#          'out': 771,
#          '&#128514;&#128514;&#128514;': 136,
#          'Lord': 8,
#          'ghetto': 179,
#          'hospital': 4,
#          'My': 363,
#          'sister': 17,
#          'called': 150,
#          'chinks': 4,
#          'an': 338,
#          'asked': 38,
#          'open': 37,
#          'ctfu': 11,
#          'she': 754,
#          'fried!!': 1,
#          '&#8220;@thejanicexxx:': 1,
#          'o': 11,
#          'dm': 11,
#          'u,': 6,
#          "i'll": 5,
#          'say': 354,
#          'here,': 7,
#          "you're": 304,
#          'rude': 14,
#          'cunt': 146,
#          'lmao&#8221;': 3,
#          'can': 565,
#          'How': 123,
#          'not': 791,
#          'style': 6,
#          'niccas': 81,
#          'taking': 41,
#          'WAY': 4,
#          'before.....Preach': 1,
#          '@1future': 2,
#          '&#128175;': 47,
#          '#RNS': 3,
#          'Russel': 2,
#          'Martin': 5,
#          'had': 252,
#          'miserable': 8,
#          'season': 31,
#          'quietly': 1,
#          'having': 106,
#          'good': 311,
#          'September': 1,
#          '#Yankees': 71,
#          '#BlueJays': 3,
#          '#MLB': 11,
#          'Just': 149,
#          'rich.': 3,
#          'Took': 8,
#          'broke': 93,
#          'nigga': 763,
#          'These': 223,
#          'ho%e$': 1,
#          'everybody': 57,
#          'these': 797,
#          'niggahs': 26,
#          'everybody!': 4,
#          'regardless': 10,
#          '(cont)': 6,
#          'http://t.co/m09Dow96rw': 1,
#          '@SenorSteez:': 6,
#          'Man,': 5,
#          'now': 283,
#          '&#128514;&#128176;&#128182;&#128184;': 1,
#          '#TheJigIsUp': 1,
#          'http://t.co/8W9Ag3bx1a': 1,
#          'dont': 208,
#          'even': 286,
#          'need': 342,
#          'picture': 36,
#          'tamar,': 1,
#          'beat': 107,
#          'every': 172,
#          'picture"&#128514;&#128557;&#128514;&#128514;&#128514;': 1,
#          '@tishforprez:': 1,
#          'pointy': 2,
#          'nail': 3,
#          'game': 135,
#          'da': 243,
#          'birds.': 27,
#          'Famous': 2,
#          'women': 91,
#          'hoes.': 93,
#          'fucked': 129,
#          'right': 262,
#          'night': 92,
#          'Till': 3,
#          'Michonne': 1,
#          'gutted': 1,
#          'dat': 204,
#          '@Fant4stic63:': 1,
#          'Can': 60,
#          'kids': 57,
#          'much': 141,
#          'their': 263,
#          'parents': 21,
#          'pay': 55,
#          'everything?': 2,
#          '@Andrea_Michele:': 1,
#          'If': 484,
#          'paying': 9,
#          'bill,': 1,
#          'complain': 18,
#          'abo&#8230;': 15,
#          '@DestroTheNoble:': 1,
#          'support': 21,
#          'ya': 323,
#          'idiot.': 2,
#          'if': 687,
#          'teabagger': 20,
#          'being': 277,
#          'teabagged.': 1,
#          '#OpenWide': 1,
#          '@nekolin': 3,
#          '@1SleepingGiant': 4,
#          "Don't": 159,
#          'yo': 410,
#          'killed': 32,
#          'new': 172,
#          'Atlanta': 3,
#          'baby!': 1,
#          '@tyler_wilde': 3,
#          'As': 35,
#          'in,': 10,
#          '"throw': 1,
#          'birds': 134,
#          'long': 76,
#          'beaks': 1,
#          'you"?': 1,
#          'Brady': 9,
#          'heard': 40,
#          'yall': 137,
#          'washed,': 1,
#          'washing': 4,
#          'league': 7,
#          'niggas.': 23,
#          '@DaOfficialPRIME:': 1,
#          '&#128514;': 231,
#          '&#128514;RT': 4,
#          '@WestSideFlee:': 2,
#          'wife': 51,
#          'let': 232,
#          'lick': 25,
#          'head': 88,
#          'public?': 2,
#          '@GlitteredInPink': 2,
#          'tweet': 82,
#          '@ItsMander': 3,
#          '@kfc': 1,
#          'always': 218,
#          'gets': 81,
#          'colored': 132,
#          'folk': 26,
#          'cage': 1,
#          'KFC': 3,
#          'Niggas': 105,
#          'sleepin': 2,
#          'bitches': 2032,
#          'grandmas???': 1,
#          'Lmfao': 25,
#          'maury': 1,
#          'fake': 69,
#          'af': 52,
#          '@XBL_NexXx:': 1,
#          'faggots': 54,
#          'posting': 15,
#          'faces': 7,
#          'hot': 80,
#          'unfollow': 16,
#          '@BlissTabitha:': 1,
#          'Homeowner': 1,
#          'Shoots': 1,
#          'Armed': 1,
#          'Suspect': 1,
#          'Attacked': 1,
#          'Pistol': 1,
#          'Whipped': 4,
#          'Him': 4,
#          'http://t.co/VLuEwUGclg': 1,
#          'GA': 1,
#          'Charlie': 203,
#          '@Charlie4927': 8,
#          '@sholzbee': 1,
#          '@DorisTafoya1': 1,
#          '@cat_lmbo': 1,
#          '@Jagauress': 1,
#          '@Walter_lars': 1,
#          '@lynnemrnp': 1,
#          '@AmyMek': 2,
#          '@Justin_Awe': 1,
#          'Technology': 1,
#          "ain't": 685,
#          'doin': 18,
#          'nothing,': 4,
#          'making': 74,
#          'look': 320,
#          'better': 187,
#          '"Brownies': 1,
#          'brownie"': 1,
#          'movie.': 3,
#          '&#128517;': 7,
#          '@leandr321:': 3,
#          'keep': 156,
#          'cause': 204,
#          'put': 177,
#          'hoze': 1,
#          "'": 100,
#          'trippen': 4,
#          'anyways': 9,
#          ',': 283,
#          'niggah': 198,
#          'girl': 276,
#          'yea': 40,
#          '&#1041196;': 2,
#          '@Lpietrantonio:': 1,
#          'BPG': 1,
#          '@KEIRRANicolee': 1,
#          "didn't": 120,
#          'following': 16,
#          'Keep': 23,
#          'real,': 7,
#          'real.': 10,
#          'Nigga': 56,
#          "couldn't": 58,
#          'wait': 51,
#          'squeal': 2,
#          '@QVC': 1,
#          'strawberry': 3,
#          'shortcake.': 1,
#          'Stacked': 1,
#          'whipped': 9,
#          'cream,': 2,
#          'spunge-cake,': 1,
#          'sliced': 2,
#          '#strawberries': 1,
#          'freshly': 1,
#          'picked': 9,
#          'farm': 5,
#          'w/': 53,
#          'kids.': 7,
#          '@jqualley_': 1,
#          '@_BeautifulKeezy': 8,
#          'YESSSSS': 1,
#          'make': 365,
#          'girls': 164,
#          'mad': 143,
#          'Ms': 1,
#          'St': 6,
#          'aint': 182,
#          'hoe.': 107,
#          'They': 134,
#          'fuckin': 168,
#          'Auburn': 1,
#          'lmao': 159,
#          's2g': 1,
#          'roots': 2,
#          'yellow/white': 1,
#          'hair': 81,
#          'makes': 88,
#          'dirty': 41,
#          '&#128567;': 10,
#          'http://t.co/SqbYdUiZr8': 1,
#          'nope': 11,
#          '@DerekIsNormal:': 4,
#          'ordered': 9,
#          "Domino's.": 1,
#          'Am': 19,
#          'trash?': 11,
#          '@ItsYOUR_man': 2,
#          'white': 252,
#          'cousin': 13,
#          'fucker': 11,
#          'such': 112,
#          'then': 398,
#          'crazy': 92,
#          '@youngblackbitch': 1,
#          'raspy': 1,
#          'voice': 21,
#          'annoying': 31,
#          'bitch???': 1,
#          'Bumoose': 1,
#          'ducking': 1,
#          'insults': 2,
#          'scared': 30,
#          'Lmao': 68,
#          'shovel': 2,
#          'video': 43,
#          'pretty': 83,
#          'awesome,': 1,
#          'went': 87,
#          'ton': 3,
#          'bricks': 4,
#          'lol.': 28,
#          'Gotta': 20,
#          'honky': 7,
#          'riff': 3,
#          'raff': 1,
#          'savages.': 1,
#          'That': 206,
#          'all.': 14,
#          '@SaveTheBS:': 1,
#          'Get': 63,
#          'bed,': 3,
#          'bitches,': 62,
#          'only': 292,
#          'dream': 17,
#          'happy': 75,
#          'dreams.': 2,
#          '@wegomakeit:': 1,
#          'smell': 41,
#          'frum': 1,
#          'bout': 231,
#          'mile': 5,
#          'away&#128564;': 1,
#          'told': 105,
#          'little': 242,
#          'nigga,': 29,
#          '"do': 2,
#          'gun': 15,
#          'charge?"': 1,
#          "I'll": 185,
#          'slap': 35,
#          'lawyer.': 1,
#          '#HelloBrookland!': 1,
#          "We're": 9,
#          '@MonroeStMarket': 1,
#          'opening!': 1,
#          'Serving': 2,
#          'free': 60,
#          'samples': 3,
#          'cider,': 1,
#          'vegan': 1,
#          'sliders,': 1,
#          'brownies!': 1,
#          'http://t.co/BW9uYtLQu1': 1,
#          'shift': 1,
#          "won't": 101,
#          'mean': 120,
#          'im': 232,
#          'doing': 109,
#          'what': 469,
#          'by.': 1,
#          'means': 42,
#          'tweeting': 29,
#          'Yo': 52,
#          'wat': 23,
#          'talkin': 52,
#          '@KillAllSimps:': 7,
#          'Kanye': 13,
#          "Wendy's,": 1,
#          'regular': 14,
#          'deserve': 24,
#          '$200': 3,
#          'dates': 6,
#          'http://t.co/QZ3hgE&#8230;': 1,
#          'Obama&#8217;s': 3,
#          'Newly': 2,
#          'Released': 2,
#          'Gitmo': 2,
#          'Jihadi': 48,
#          'Has': 4,
#          'Links': 2,
#          'To': 35,
#          'Terrorists': 4,
#          'In': 76,
#          'Syria': 6,
#          'http://t.co/MywaAFD1yB': 1,
#          '#tcot': 32,
#          '#pjnet': 8,
#          'bringing': 10,
#          'booty': 49,
#          'back.': 28,
#          'Go': 34,
#          'ahead': 6,
#          'skinny': 34,
#          'that.': 33,
#          '@djvlad:': 1,
#          '"if': 6,
#          'sis': 4,
#          'bitch,': 192,
#          'brother': 26,
#          'jerk,': 1,
#          'leave': 57,
#          "'em": 8,
#          'both': 71,
#          'alone': 23,
#          'continue': 9,
#          'work"': 1,
#          'Q-Tip': 1,
#          'Someone': 25,
#          'household': 1,
#          'wants': 57,
#          'die.': 6,
#          'excited': 14,
#          'enjoy': 15,
#          'couple': 44,
#          'Oreos,': 1,
#          'someone': 123,
#          'left': 54,
#          'ONLY': 4,
#          'ONE.': 1,
#          'ONE': 10,
#          "FRIGGIN'": 1,
#          'OREO.': 1,
#          '&#128545;&#128548;&#128544;&#128298;&#128299;': 1,
#          '@WhenRapperSaid:': 2,
#          'Tupac': 6,
#          'killer': 7,
#          'push': 17,
#          'me,': 70,
#          'revenge': 5,
#          'sweetest': 6,
#          'joy': 5,
#          'next': 119,
#          'getting': 171,
#          'pussy"': 25,
#          'http://t.co/pto&#8230;': 1,
#          '"research"': 1,
#          'street': 22,
#          'signs': 6,
#          'near': 15,
#          'usaa': 1,
#          '.': 325,
#          'Hang': 1,
#          'above': 10,
#          'bed': 34,
#          '"@maybe6789:': 1,
#          'Now': 60,
#          'want': 416,
#          '!': 167,
#          'Enjoy': 4,
#          'http://t.co/gLQzwtGMj9"': 1,
#          'party': 46,
#          'attend.': 1,
#          '@wvjoe911:': 1,
#          'Gov': 1,
#          'Rick': 28,
#          'Scott': 21,
#          'Refuses': 2,
#          'Debate': 2,
#          'Crist': 26,
#          'Of': 23,
#          'Small': 4,
#          'Fan': 5,
#          'http://t.co/hKMfPnRukU': 1,
#          'Never': 47,
#          'give': 186,
#          'impression': 3,
#          '@MaryWCVB:': 2,
#          'Baker': 12,
#          'final': 10,
#          'election': 7,
#          'eve': 1,
#          'campaign': 7,
#          'stop-': 1,
#          'Swampscott': 2,
#          'High': 13,
#          'School.': 1,
#          '#wcvb': 5,
#          '#wcvbpoli': 2,
#          'http://t.co&#8230;': 11,
#          'Jus': 8,
#          'tired': 39,
#          'nicca': 119,
#          'Young': 13,
#          'Thug': 4,
#          'gah': 1,
#          'yesterday': 14,
#          'believe': 57,
#          '&#128530;': 66,
#          'hit': 157,
#          'tf': 65,
#          'bitch.': 425,
#          'No': 146,
#          'close': 29,
#          'fisted': 1,
#          'business': 27,
#          'though': 48,
#          "that's": 267,
#          'some': 590,
#          'cowardly': 1,
#          'shit.': 71,
#          '&#8220;@Iifetip:': 1,
#          'Kit': 1,
#          'Kat': 1,
#          'brownies.': 10,
#          'http://t.co/40W2a8qlBy&#8221;': 1,
#          'making.': 1,
#          'Good': 47,
#          'Mernin': 1,
#          'http://t.co/3ZPTPqFkTl': 1,
#          '@Pretty_N_Purrls:': 1,
#          'EX': 4,
#          '&#128080;': 13,
#          'Nobody': 16,
#          'gives': 13,
#          'trophy': 2,
#          'old': 152,
#          '#FavStarTweets&#160;': 1,
#          "What's": 27,
#          '#picslip': 2,
#          'shit?': 7,
#          'pic.': 1,
#          "IT'S": 1,
#          'NOT': 22,
#          'SLIP!': 1,
#          'flatter': 1,
#          'yourself.': 6,
#          '*stupid': 1,
#          'bitches!': 34,
#          'This': 391,
#          'really': 307,
#          'geeking': 1,
#          'messages': 4,
#          "There's": 23,
#          'bird': 220,
#          'nest': 3,
#          'garage': 2,
#          'fly': 24,
#          'poop': 7,
#          'car.': 11,
#          '&#128529;': 18,
#          '@Brandan420_:': 1,
#          '"You': 36,
#          'Weed..."': 2,
#          'sober.': 2,
#          '@0beytheLAU': 2,
#          '@Huntermoore': 24,
#          'gross': 2,
#          'as': 491,
#          'touchin': 3,
#          'saggy': 2,
#          'titties': 19,
#          '@Bigchapo_4cH:': 1,
#          '#Merched&#10004;&#128520;"@_100d:': 1,
#          'Smoke': 11,
#          'Nap': 1,
#          'play': 136,
#          'music': 53,
#          'bet': 56,
#          '100': 21,
#          'turn': 87,
#          'boosie': 7,
#          'slow': 27,
#          '&#128530;"': 6,
#          '18': 15,
#          'year': 79,
#          'tastes': 9,
#          'hope.': 2,
#          '@Meeting_aJERNed:': 1,
#          'Fam': 1,
#          '@PBS_Impulse9:': 1,
#          '"It': 2,
#          'nothin': 26,
#          'cut': 73,
#          'off"': 9,
#          '---': 3,
#          'Vincent': 2,
#          'Van': 3,
#          'Gogh': 1,
#          'players': 9,
#          '3K': 2,
#          'hits?': 1,
#          '#DerekJeter': 3,
#          'conversation': 9,
#          'Best': 13,
#          'Yankee': 45,
#          'Ever.': 3,
#          'His': 24,
#          'numbers': 8,
#          'demand': 5,
#          'it.': 125,
#          '@Alyssamichh:': 1,
#          '@Tronkitty': 4,
#          'bad': 368,
#          'bitch&#128158;': 1,
#          "Y'all": 114,
#          'suck': 65,
#          'flappy': 42,
#          '@iaintshitbruh:': 1,
#          'win': 39,
#          'again': 60,
#          'smh': 95,
#          '&#8220;@trackinBlackKev:': 1,
#          'fucking': 464,
#          'hate': 321,
#          '@MichelleDBeadle&#8221;': 1,
#          '@CaelanG15': 2,
#          'eating': 66,
#          '@M_A_Larson': 1,
#          '@SteveStreza': 1,
#          "You're": 81,
#          'zebras': 5,
#          'are': 856,
#          'goth?': 1,
#          '@laceeybugg': 3,
#          'talker': 2,
#          'youre': 24,
#          'short': 18,
#          'stfu': 53,
#          'lonely&#128514;&#128514;': 1,
#          '&#128553;&#128514;&#9995;': 1,
#          '@SexualTruth:': 4,
#          'Eating': 9,
#          'womans': 3,
#          'soul.': 3,
#          '4th': 7,
#          '@caycifish': 1,
#          'What': 143,
#          'poor': 19,
#          'bottles?': 1,
#          '@AdamSchein:': 2,
#          'think': 355,
#          'flat': 15,
#          'wrong': 79,
#          'blame': 22,
#          'Brian': 6,
#          'Cashman': 2,
#          '2014': 25,
#          'Yankees.': 6,
#          '@SNYtv': 1,
#          'comes': 49,
#          "friends'": 1,
#          'hostel': 1,
#          'iii': 1,
#          "we're": 14,
#          'watching': 53,
#          '@selenalinn_': 1,
#          'jets': 2,
#          'see': 343,
#          'meant': 16,
#          '@hotzgeor': 1,
#          'Kept': 1,
#          'border': 9,
#          'disease': 5,
#          'Central': 2,
#          'America,': 4,
#          'lowest': 2,
#          'workforce': 1,
#          'part.': 2,
#          '%': 3,
#          'since': 74,
#          'Carter,': 1,
#          'yep,': 2,
#          'real': 255,
#          'boon': 7,
#          'NC.@ThomTillis': 1,
#          '@JTrevorHowerton': 2,
#          '@HollyRFisher': 2,
#          'because': 232,
#          'hilarious': 8,
#          'how': 420,
#          'teabaggers': 15,
#          'freak': 13,
#          'out.': 23,
#          'too.': 33,
#          'cute': 74,
#          'without': 62,
#          'makeup': 8,
#          'eyelashes': 5,
#          '&#128076;&#128524;': 1,
#          'depend': 2,
#          '@joshkline1992': 1,
#          'nig': 74,
#          'nog': 7,
#          'Its': 54,
#          'wayyyyy': 1,
#          'more': 254,
#          'going': 208,
#          '2': 165,
#          'pushing': 4,
#          '@dbrend99:': 1,
#          'Even': 30,
#          'there': 184,
#          'Derek': 20,
#          'Jeter,': 1,
#          'classiest': 1,
#          'most': 101,
#          'respectful': 1,
#          'playe&#8230;': 1,
#          'Well': 46,
#          'wish': 79,
#          'could': 146,
#          'shoot': 36,
#          'daddy': 21,
#          'gotta': 205,
#          'dis': 71,
#          'money': 146,
#          '.one': 1,
#          'Why': 130,
#          'eyes': 46,
#          'siblings': 1,
#          '&#128557;&#128557;': 8,
#          '@HobsonDarlene:': 1,
#          '"@1Corinthians126:': 1,
#          '@HobsonDarlene': 1,
#          '#BlessJesus': 5,
#          'Amos': 8,
#          '3:3': 2,
#          'two': 108,
#          'walk': 41,
#          'together,': 6,
#          'unless': 29,
#          'agreed?': 2,
#          '#DifferentLevels"': 1,
#          '&#8230;': 130,
#          '@ockfromdablock:': 1,
#          'animals': 3,
#          'grabbed': 2,
#          'mama': 25,
#          'bitch&#128548;': 1,
#          'http://t.co/sulNMnC&#8230;': 1,
#          '@wutkarina': 1,
#          'Alright': 2,
#          'fag': 134,
#          'liked': 13,
#          '@YouTube': 6,
#          'http://t.co/QGNHiLdTTv': 1,
#          ...})

# %%
from nltk.tokenize import TweetTokenizer
tknzr = TweetTokenizer()

# %%
# get unigram counts for data
def get_unigrams_nltkTokenizer():
    uni = Counter()
    tweets = train_data[['tweet']]
    for row_index, row in tweets.iterrows():
        s = tknzr.tokenize(row['tweet'])
        for word in s:
            #print(word, type(word), type(s))
            uni[word] += 1  
    #print(uni)
    return uni

# %%
u = get_unigrams_nltkTokenizer()
u
# Out:
# Counter({'Kim': 22,
#          'K': 19,
#          'is': 2241,
#          'alright': 12,
#          'but': 1034,
#          'honestly': 17,
#          'so': 897,
#          'many': 136,
#          'niggas': 508,
#          'been': 261,
#          'in': 2410,
#          'that': 2550,
#          "I'd": 83,
#          'rather': 54,
#          'not': 827,
#          '..': 853,
#          'And': 209,
#          'Miley': 10,
#          'got': 951,
#          'unfollowed': 7,
#          'bitch': 6518,
#          'just': 1002,
#          'strange': 2,
#          '.': 8001,
#          "I'm": 1264,
#          'mother': 37,
#          'fucken': 6,
#          'sexy': 38,
#          'I': 5428,
#          'have': 777,
#          'no': 851,
#          'time': 326,
#          'to': 4217,
#          'be': 1896,
#          'a': 7274,
#          'retard': 91,
#          'RT': 6081,
#          '@Booskerz': 1,
#          ':': 8187,
#          '"': 4118,
#          '@DailySexSupply': 2,
#          'Girls': 28,
#          'fuck': 933,
#          'back': 345,
#          '>': 186,
#          '😍': 131,
#          'http://t.co/pI064ylhF6': 1,
#          '@iDocLyfe': 9,
#          'your': 1112,
#          'last': 134,
#          'one': 518,
#          'was': 906,
#          'trash': 923,
#          'here': 268,
#          'Think': 6,
#          "it's": 347,
#          'okay': 43,
#          'take': 214,
#          'my': 2482,
#          'property': 3,
#          'and': 2949,
#          'break': 56,
#          'it': 1431,
#          '?': 2016,
#          'Fuck': 185,
#          'you': 4212,
#          'Apologizing': 1,
#          'advance': 1,
#          'for': 1675,
#          'actions': 4,
#          ',': 4842,
#          'thee': 3,
#          'biggest': 24,
#          'when': 773,
#          'studying': 3,
#          '😊': 26,
#          '🔫': 48,
#          'She': 165,
#          'used': 63,
#          'wit': 278,
#          'A': 287,
#          '$': 95,
#          'AP': 5,
#          'Too': 27,
#          'Shortsaid': 1,
#          'he': 608,
#          'know': 626,
#          'from': 437,
#          'way': 163,
#          '@elise_palmer': 3,
#          'sounds': 26,
#          'like': 2112,
#          'gypos': 1,
#          'me': 2096,
#          '-': 441,
#          'they': 947,
#          'do': 603,
#          'this': 1291,
#          'all': 1007,
#          'the': 5285,
#          'where': 175,
#          'lived': 7,
#          'Quit': 13,
#          'blowing': 7,
#          'up': 1204,
#          'feed': 20,
#          'bitches': 2368,
#          'please': 81,
#          'tell': 223,
#          'subbin': 2,
#          'her': 914,
#          'ik': 10,
#          'of': 1994,
#          'faggs': 1,
#          'on': 1919,
#          'with': 1473,
#          'those': 149,
#          'lames': 2,
#          'shit': 947,
#          'blocked': 17,
#          'or': 524,
#          'would': 301,
#          'lol': 633,
#          'never': 304,
#          'lie': 48,
#          'cry': 43,
#          'die': 69,
#          'we': 466,
#          'gone': 139,
#          'love': 517,
#          'friends': 100,
#          'hoes': 1835,
#          'yellow': 204,
#          'sluts': 12,
#          'call': 224,
#          'them': 536,
#          'gold': 21,
#          '@ChiefKeef': 10,
#          'You': 642,
#          'niggaz': 32,
#          'get': 1064,
#          'emotionaaaal': 1,
#          'remind': 8,
#          '!': 3190,
#          '#tbt': 9,
#          'i': 724,
#          'took': 62,
#          'likkle': 1,
#          'monkey': 138,
#          'jimmys': 2,
#          'http://t.co/LIK3xpZ6eZ': 1,
#          '@MisterDimmadome': 1,
#          'spiked': 2,
#          'damned': 4,
#          'nailed': 2,
#          'down': 248,
#          'pull': 54,
#          'eat': 176,
#          'pussy': 1678,
#          'dip': 6,
#          '@NotWorldStar': 1,
#          'When': 275,
#          'drop': 43,
#          'person': 63,
#          "y'all": 225,
#          "don't": 1019,
#          'end': 51,
#          'together': 52,
#          'http://t.co/lLViTXweMX': 1,
#          '@danwashburn': 1,
#          'The': 410,
#          'Man': 58,
#          'Who': 61,
#          'Captured': 1,
#          'Muammar': 1,
#          'Gaddafi': 1,
#          'Was': 16,
#          'Wearing': 1,
#          'Yankees': 113,
#          'Cap': 1,
#          'http://t.co/7G70pOpW': 1,
#          'Yall': 43,
#          'Skip': 1,
#          'Bayless': 1,
#          'about': 729,
#          'slit': 20,
#          'his': 403,
#          'wrists': 3,
#          'over': 282,
#          'Romo': 4,
#          'Lol': 181,
#          '@Chill__Nigga': 1,
#          "can't": 397,
#          'twenties': 2,
#          'stressing': 4,
#          'who': 464,
#          'playin': 31,
#          'games': 47,
#          'straight': 78,
#          '@_xxsarafina': 1,
#          'haha': 98,
#          'hoe': 1531,
#          'go': 467,
#          'hard': 97,
#          'rt': 22,
#          'Kevin': 8,
#          'hart': 3,
#          '4': 92,
#          '8': 45,
#          '👋': 35,
#          'hi-ho': 1,
#          'http://t.co/FiC4FnRutZ': 1,
#          '@itskingdee': 3,
#          '@1inkkofrosess': 18,
#          'bigger': 21,
#          'problems': 29,
#          'cook': 21,
#          'at': 845,
#          'house': 93,
#          '@NYRKelsMads': 12,
#          '@DaniloNavarro85': 1,
#          'Hey': 42,
#          'fag': 175,
#          'said': 317,
#          'aunts': 2,
#          '*': 380,
#          'He': 126,
#          '@OfficialKingDre': 3,
#          'WTF': 8,
#          'did': 153,
#          '😂': 2219,
#          'https://t.co/5BFuSp9bfn': 1,
#          '@Cajun_peach': 1,
#          'Because': 22,
#          'humans': 3,
#          "aren't": 34,
#          'delicious': 3,
#          'ho': 151,
#          '@peta': 3,
#          'Smarter': 1,
#          'than': 281,
#          'dogs': 16,
#          'AND': 14,
#          '3': 128,
#          'year-old': 3,
#          'child': 20,
#          'So': 171,
#          'why': 304,
#          'EAT': 3,
#          'http://t.co/eRT…': 1,
#          'will': 336,
#          'u': 926,
#          'stand': 60,
#          'U': 98,
#          'dizzy': 1,
#          'Two': 17,
#          'unique': 4,
#          '&': 750,
#          'separate': 3,
#          'phrases': 1,
#          'overheard': 1,
#          'relative': 2,
#          'saying': 90,
#          'younger': 7,
#          '“': 1370,
#          '@MattieTrump97': 2,
#          'Eat': 25,
#          'lot': 94,
#          'protein': 1,
#          '#MattieTrumpsTipsForABetterLife': 1,
#          '”': 1288,
#          'whole': 58,
#          'ass': 1235,
#          'rebuild': 1,
#          'tranny': 44,
#          'driving': 18,
#          'its': 178,
#          'years': 69,
#          'till': 39,
#          'finally': 19,
#          'goes': 41,
#          'out': 845,
#          'Lord': 11,
#          'ghetto': 213,
#          'hospital': 5,
#          'My': 381,
#          'sister': 25,
#          'called': 151,
#          'chinks': 5,
#          'an': 344,
#          'asked': 39,
#          'open': 42,
#          'ctfu': 11,
#          'she': 776,
#          'fried': 14,
#          '@thejanicexxx': 1,
#          'o': 56,
#          'dm': 14,
#          "i'll": 5,
#          'say': 378,
#          "you're": 309,
#          'rude': 15,
#          'cunt': 206,
#          'lmao': 190,
#          'can': 585,
#          'How': 133,
#          'style': 7,
#          'niccas': 91,
#          'taking': 42,
#          'WAY': 5,
#          'before': 144,
#          '...': 1674,
#          'Preach': 2,
#          '@1future': 2,
#          '💯': 190,
#          '#RNS': 3,
#          'Russel': 2,
#          'Martin': 8,
#          'had': 261,
#          'miserable': 8,
#          'season': 42,
#          'quietly': 1,
#          'having': 107,
#          'good': 345,
#          'September': 1,
#          '#Yankees': 74,
#          '#BlueJays': 3,
#          '#MLB': 12,
#          'Just': 152,
#          'rich': 45,
#          'Took': 8,
#          'broke': 103,
#          'nigga': 891,
#          'These': 228,
#          '%': 67,
#          'e': 10,
#          'everybody': 73,
#          'these': 812,
#          'niggahs': 26,
#          'regardless': 10,
#          '(': 154,
#          'cont': 6,
#          ')': 179,
#          'http://t.co/m09Dow96rw': 1,
#          '@SenorSteez': 7,
#          'now': 402,
#          '💰': 22,
#          '💶': 1,
#          '💸': 15,
#          '#TheJigIsUp': 1,
#          'http://t.co/8W9Ag3bx1a': 1,
#          'dont': 211,
#          'even': 289,
#          'need': 347,
#          'picture': 40,
#          'tamar': 1,
#          'beat': 111,
#          'every': 174,
#          '😭': 400,
#          '@tishforprez': 1,
#          'pointy': 2,
#          'nail': 3,
#          'game': 161,
#          'da': 243,
#          'birds': 188,
#          'Famous': 2,
#          'women': 108,
#          'fucked': 134,
#          'right': 301,
#          'night': 128,
#          'Till': 3,
#          'Michonne': 1,
#          'gutted': 1,
#          'dat': 210,
#          '@Fant4stic63': 1,
#          'Can': 65,
#          'kids': 83,
#          'much': 167,
#          'their': 268,
#          'parents': 23,
#          'pay': 58,
#          'everything': 68,
#          '@Andrea_Michele': 1,
#          'If': 496,
#          'paying': 9,
#          'bill': 11,
#          'complain': 21,
#          'abo': 19,
#          '…': 881,
#          '@DestroTheNoble': 3,
#          'support': 28,
#          'ya': 334,
#          'idiot': 8,
#          'if': 702,
#          'teabagger': 20,
#          'being': 282,
#          'teabagged': 1,
#          '#OpenWide': 1,
#          '@nekolin': 3,
#          '@1SleepingGiant': 5,
#          "Don't": 167,
#          'yo': 425,
#          'killed': 35,
#          'new': 174,
#          'Atlanta': 6,
#          'baby': 116,
#          '@tyler_wilde': 3,
#          'As': 36,
#          'throw': 72,
#          'long': 85,
#          'beaks': 1,
#          'Brady': 9,
#          'heard': 43,
#          'yall': 146,
#          'washed': 8,
#          'washing': 4,
#          'league': 10,
#          '@DaOfficialPRIME': 1,
#          '@WestSideFlee': 4,
#          'wife': 67,
#          'let': 238,
#          'lick': 26,
#          'head': 117,
#          'public': 35,
#          '@GlitteredInPink': 5,
#          'tweet': 101,
#          '@ItsMander': 3,
#          '@kfc': 1,
#          'always': 220,
#          'gets': 82,
#          'colored': 138,
#          'folk': 32,
#          'cage': 1,
#          'KFC': 3,
#          'Niggas': 111,
#          'sleepin': 2,
#          'grandmas': 3,
#          'Lmfao': 27,
#          'maury': 1,
#          'fake': 74,
#          'af': 62,
#          '@XBL_NexXx': 1,
#          'faggots': 73,
#          'posting': 15,
#          'faces': 12,
#          'hot': 88,
#          'unfollow': 17,
#          '@BlissTabitha': 1,
#          'Homeowner': 1,
#          'Shoots': 1,
#          'Armed': 1,
#          'Suspect': 1,
#          'Attacked': 1,
#          'Pistol': 2,
#          'Whipped': 4,
#          'Him': 7,
#          'http://t.co/VLuEwUGclg': 1,
#          'GA': 1,
#          'Charlie': 227,
#          '@Charlie4927': 8,
#          '@sholzbee': 1,
#          '@DorisTafoya1': 1,
#          '@cat_lmbo': 1,
#          '@Jagauress': 1,
#          '@Walter_lars': 1,
#          '@lynnemrnp': 1,
#          '@AmyMek': 2,
#          '@Justin_Awe': 1,
#          'Technology': 1,
#          "ain't": 689,
#          'doin': 24,
#          'nothing': 100,
#          'making': 75,
#          'look': 335,
#          'better': 204,
#          'Brownies': 2,
#          'brownie': 35,
#          'movie': 37,
#          '😅': 15,
#          '@leandr321': 3,
#          'keep': 161,
#          'cause': 208,
#          'put': 180,
#          'hoze': 1,
#          "'": 485,
#          'trippen': 4,
#          'anyways': 20,
#          'niggah': 212,
#          'girl': 316,
#          'yea': 50,
#          '\U000fe32c': 6,
#          '@Lpietrantonio': 1,
#          'BPG': 1,
#          '@KEIRRANicolee': 1,
#          "didn't": 120,
#          'following': 16,
#          'Keep': 26,
#          'real': 285,
#          'Nigga': 62,
#          "couldn't": 58,
#          'wait': 68,
#          'squeal': 2,
#          '@QVC': 1,
#          'strawberry': 4,
#          'shortcake': 1,
#          'Stacked': 1,
#          'whipped': 9,
#          'cream': 28,
#          'spunge-cake': 1,
#          'sliced': 2,
#          '#strawberries': 1,
#          'freshly': 1,
#          'picked': 9,
#          'farm': 6,
#          'w': 122,
#          '/': 266,
#          '@jqualley_': 1,
#          '@_BeautifulKeezy': 27,
#          'YESSSSS': 1,
#          'make': 366,
#          'girls': 191,
#          'mad': 161,
#          'Ms': 2,
#          'St': 10,
#          'aint': 186,
#          'They': 140,
#          'fuckin': 186,
#          'Auburn': 1,
#          's2g': 1,
#          'roots': 2,
#          'white': 265,
#          'hair': 94,
#          'makes': 89,
#          'dirty': 43,
#          '😷': 28,
#          'http://t.co/SqbYdUiZr8': 1,
#          'nope': 18,
#          '@DerekIsNormal': 6,
#          'ordered': 9,
#          "Domino's": 1,
#          'Am': 19,
#          '@ItsYOUR_man': 2,
#          'cousin': 14,
#          'fucker': 13,
#          'such': 112,
#          'then': 421,
#          'crazy': 112,
#          '@youngblackbitch': 1,
#          'raspy': 1,
#          'voice': 39,
#          'annoying': 36,
#          'Bumoose': 1,
#          'ducking': 1,
#          'insults': 3,
#          'scared': 30,
#          'Lmao': 88,
#          'shovel': 3,
#          'video': 48,
#          'pretty': 91,
#          'awesome': 14,
#          'went': 89,
#          'ton': 3,
#          'bricks': 4,
#          'Gotta': 20,
#          'honky': 10,
#          'riff': 3,
#          'raff': 2,
#          'savages': 4,
#          'That': 216,
#          '@SaveTheBS': 1,
#          'Get': 65,
#          'bed': 46,
#          'only': 302,
#          'dream': 21,
#          'happy': 93,
#          'dreams': 11,
#          '@wegomakeit': 1,
#          'smell': 44,
#          'frum': 1,
#          'bout': 237,
#          'mile': 5,
#          'away': 81,
#          '😴': 99,
#          'told': 107,
#          'little': 247,
#          'gun': 18,
#          'charge': 12,
#          "I'll": 195,
#          'slap': 35,
#          'lawyer': 2,
#          '#HelloBrookland': 1,
#          "We're": 12,
#          '@MonroeStMarket': 1,
#          'opening': 2,
#          'Serving': 2,
#          'free': 65,
#          'samples': 3,
#          'cider': 1,
#          'vegan': 1,
#          'sliders': 1,
#          'brownies': 70,
#          'http://t.co/BW9uYtLQu1': 1,
#          'shift': 3,
#          "won't": 104,
#          'mean': 137,
#          'im': 240,
#          'doing': 115,
#          'what': 524,
#          'by': 275,
#          'means': 43,
#          'tweeting': 30,
#          'Yo': 61,
#          'wat': 24,
#          'talkin': 54,
#          '@KillAllSimps': 7,
#          'Kanye': 15,
#          "Wendy's": 1,
#          'regular': 14,
#          'deserve': 25,
#          '200': 8,
#          'dates': 8,
#          'http://t.co/QZ3hgE…': 1,
#          'Obama': 36,
#          '’': 223,
#          's': 143,
#          'Newly': 2,
#          'Released': 2,
#          'Gitmo': 2,
#          'Jihadi': 49,
#          'Has': 5,
#          'Links': 2,
#          'To': 36,
#          'Terrorists': 4,
#          'In': 80,
#          'Syria': 7,
#          'http://t.co/MywaAFD1yB': 1,
#          '#tcot': 33,
#          '#pjnet': 8,
#          'bringing': 10,
#          'booty': 52,
#          'Go': 41,
#          'ahead': 8,
#          'skinny': 34,
#          '@djvlad': 1,
#          'sis': 8,
#          'brother': 29,
#          'jerk': 5,
#          'leave': 61,
#          'em': 153,
#          'both': 78,
#          'alone': 33,
#          'continue': 10,
#          'work': 125,
#          'Q-Tip': 1,
#          'Someone': 26,
#          'household': 1,
#          'wants': 59,
#          'excited': 15,
#          'enjoy': 17,
#          'couple': 47,
#          'Oreos': 45,
#          'someone': 130,
#          'left': 61,
#          'ONLY': 5,
#          'ONE': 11,
#          'FRIGGIN': 1,
#          'OREO': 1,
#          '😡': 45,
#          '😤': 33,
#          '😠': 11,
#          '🔪': 14,
#          '@WhenRapperSaid': 2,
#          'Tupac': 7,
#          'killer': 7,
#          'push': 17,
#          'revenge': 5,
#          'sweetest': 6,
#          'joy': 6,
#          'next': 127,
#          'getting': 173,
#          'http://t.co/pto…': 1,
#          'research': 2,
#          'street': 27,
#          'signs': 7,
#          'near': 15,
#          'usaa': 1,
#          'Hang': 1,
#          'above': 11,
#          '@maybe6789': 1,
#          'Now': 67,
#          'want': 434,
#          'Enjoy': 4,
#          'http://t.co/gLQzwtGMj9': 1,
#          'party': 58,
#          'attend': 5,
#          '@wvjoe911': 1,
#          'Gov': 9,
#          'Rick': 30,
#          'Scott': 24,
#          'Refuses': 2,
#          'Debate': 2,
#          'Crist': 32,
#          'Of': 23,
#          'Small': 4,
#          'Fan': 5,
#          'http://t.co/hKMfPnRukU': 1,
#          'Never': 49,
#          'give': 188,
#          'impression': 4,
#          '@MaryWCVB': 2,
#          'Baker': 16,
#          'final': 10,
#          'election': 11,
#          'eve': 3,
#          'campaign': 7,
#          'stop': 205,
#          'Swampscott': 2,
#          'High': 13,
#          'School': 11,
#          '#wcvb': 5,
#          '#wcvbpoli': 2,
#          'http://t.co…': 11,
#          'Jus': 8,
#          'tired': 44,
#          'nicca': 134,
#          'Young': 18,
#          'Thug': 4,
#          'gah': 1,
#          'yesterday': 17,
#          'believe': 58,
#          '😒': 198,
#          'hit': 163,
#          'tf': 69,
#          'No': 169,
#          'close': 31,
#          'fisted': 1,
#          'business': 34,
#          'though': 81,
#          "that's": 275,
#          'some': 600,
#          'cowardly': 1,
#          '@Iifetip': 1,
#          'Kit': 1,
#          'Kat': 1,
#          'http://t.co/40W2a8qlBy': 1,
#          'Good': 53,
#          'Mernin': 1,
#          'http://t.co/3ZPTPqFkTl': 1,
#          '@Pretty_N_Purrls': 1,
#          'EX': 4,
#          '👐': 48,
#          'Nobody': 17,
#          'gives': 13,
#          'trophy': 2,
#          'old': 160,
#          '#FavStarTweets': 1,
#          "What's": 27,
#          '#picslip': 2,
#          'pic': 58,
#          "IT'S": 1,
#          'NOT': 23,
#          'SLIP': 1,
#          'flatter': 1,
#          'yourself': 47,
#          'stupid': 164,
#          'This': 399,
#          'really': 317,
#          'geeking': 1,
#          'messages': 4,
#          "There's": 24,
#          'bird': 281,
#          'nest': 3,
#          'garage': 2,
#          'fly': 28,
#          'poop': 9,
#          'car': 87,
#          '😑': 41,
#          '@Brandan420_': 1,
#          'Weed': 8,
#          'sober': 8,
#          '@0beytheLAU': 2,
#          '@Huntermoore': 25,
#          'gross': 6,
#          'as': 495,
#          'touchin': 3,
#          'saggy': 2,
#          'titties': 20,
#          '@Bigchapo_4cH': 1,
#          '#Merched': 1,
#          '✔': 3,
#          '😈': 52,
#          '@_100d': 6,
#          'Smoke': 11,
#          'Nap': 1,
#          'play': 145,
#          'music': 64,
#          'bet': 62,
#          '100': 38,
#          'turn': 93,
#          'boosie': 7,
#          'slow': 29,
#          '18': 17,
#          'year': 107,
#          'tastes': 9,
#          'hope': 75,
#          '@Meeting_aJERNed': 1,
#          'Fam': 2,
#          '@PBS_Impulse9': 1,
#          'It': 114,
#          'nothin': 37,
#          'cut': 76,
#          'off': 359,
#          'Vincent': 2,
#          'Van': 3,
#          'Gogh': 1,
#          'players': 13,
#          '3K': 2,
#          'hits': 17,
#          '#DerekJeter': 3,
#          'conversation': 9,
#          'Best': 13,
#          'Yankee': 51,
#          'Ever': 8,
#          'His': 25,
#          'numbers': 8,
#          'demand': 5,
#          '@Alyssamichh': 1,
#          '@Tronkitty': 4,
#          'bad': 416,
#          '💞': 4,
#          "Y'all": 115,
#          'suck': 74,
#          'flappy': 42,
#          '@iaintshitbruh': 1,
#          'win': 51,
#          'again': 105,
#          'smh': 115,
#          '@trackinBlackKev': 2,
#          'fucking': 473,
#          'hate': 329,
#          '@MichelleDBeadle': 1,
#          '@CaelanG15': 2,
#          'eating': 69,
#          '@M_A_Larson': 1,
#          '@SteveStreza': 1,
#          "You're": 87,
#          'zebras': 7,
#          'are': 903,
#          'goth': 3,
#          '@laceeybugg': 3,
#          'talker': 5,
#          'youre': 24,
#          'short': 21,
#          'stfu': 62,
#          'lonely': 23,
#          '😩': 292,
#          '✋': 74,
#          '@SexualTruth': 4,
#          'Eating': 11,
#          'womans': 3,
#          'soul': 23,
#          '4th': 7,
#          '@caycifish': 1,
#          'What': 165,
#          'poor': 24,
#          'bottles': 7,
#          '@AdamSchein': 2,
#          'think': 362,
#          'flat': 16,
#          'wrong': 93,
#          'blame': 22,
#          'Brian': 7,
#          'Cashman': 2,
#          '2014': 30,
#          '@SNYtv': 1,
#          'comes': 50,
#          'hostel': 1,
#          'iii': 1,
#          "we're": 15,
#          'watching': 55,
#          '@selenalinn_': 1,
#          'jets': 2,
#          'see': 356,
#          'meant': 16,
#          '@hotzgeor': 1,
#          'Kept': 1,
#          'border': 13,
#          'disease': 5,
#          'Central': 2,
#          'America': 31,
#          'lowest': 2,
#          'workforce': 1,
#          'part': 23,
#          'since': 77,
#          'Carter': 4,
#          'yep': 5,
#          'boon': 7,
#          'NC': 1,
#          '@ThomTillis': 1,
#          '@JTrevorHowerton': 2,
#          '@HollyRFisher': 2,
#          'because': 233,
#          'hilarious': 12,
#          'how': 428,
#          'teabaggers': 23,
#          'freak': 14,
#          'too': 381,
#          'cute': 99,
#          'without': 63,
#          'makeup': 9,
#          'eyelashes': 6,
#          '👌': 90,
#          '😌': 48,
#          'depend': 2,
#          '@joshkline1992': 1,
#          'nig': 98,
#          'nog': 7,
#          'Its': 54,
#          'wayyyyy': 1,
#          'more': 276,
#          'going': 216,
#          '2': 206,
#          'pushing': 4,
#          '@dbrend99': 1,
#          'Even': 33,
#          'there': 215,
#          'Derek': 20,
#          'Jeter': 30,
#          'classiest': 1,
#          'most': 103,
#          'respectful': 2,
#          'playe': 1,
#          'Well': 60,
#          'wish': 92,
#          'could': 148,
#          'shoot': 38,
#          'daddy': 24,
#          'gotta': 205,
#          'dis': 72,
#          'money': 191,
#          'Why': 143,
#          'eyes': 59,
#          'siblings': 1,
#          '@HobsonDarlene': 2,
#          '@1Corinthians126': 3,
#          '#BlessJesus': 5,
#          'Amos': 9,
#          '3:3': 2,
#          'two': 113,
#          'walk': 44,
#          'unless': 30,
#          'agreed': 5,
#          '#DifferentLevels': 1,
#          '@ockfromdablock': 1,
#          'animals': 5,
#          'grabbed': 2,
#          'mama': 31,
#          'http://t.co/sulNMnC…': 1,
#          '@wutkarina': 1,
#          'Alright': 5,
#          'liked': 13,
#          '@YouTube': 7,
#          'http://t.co/QGNHiLdTTv': 1,
#          'Sock': 2,
#          'Fairy': 16,
#          'film': 9,
#          'Her': 27,
#          'wet': 39,
#          'Fiji': 1,
#          'water': 40,
#          '#WhyIHateInstagram': 1,
#          'cheat': 39,
#          'four': 7,
#          'points': 15,
#          'scale': 10,
#          '1': 124,
#          '10': 75,
#          'snow': 6,
#          'day': 236,
#          'lyrics': 9,
#          'gettin': 42,
#          'done': 105,
#          'n': 219,
#          'bud': 13,
#          'smoked': 5,
#          '#snowday2014': 1,
#          '@SarcasmLeague': 2,
#          'Back': 12,
#          'elementary': 6,
#          'school': 129,
#          'were': 134,
#          'line': 60,
#          'leader': 7,
#          'else': 57,
#          '@NoRapist': 3,
#          'Throwing': 4,
#          'lamps': 2,
#          'lighten': 1,
#          'True': 9,
#          '@englandlauren': 1,
#          ...})

# %%
# 
def get_bigrams():
    bigrams = Counter()
    tweets = train_data[['tweet']]
    start = "<s>"
    end = "</s>"
    for row_index,row in tweets.iterrows():
        s = row['tweet'].split()
        word = start + " " + s[0]
        bigrams[word] += 1
        for i in range(len(s)-1):
            word = s[i] + " " + s[i+1]
            bigrams[word] += 1
        word = s[len(s) - 1] + " " + end
        bigrams[word] += 1
    #print(bigrams)
    return bigrams

# %%
#Gets the average word counts for data
#maybe split tweet on more than just whitespace ie ;:,.')(
def get_avg_wc():
    wcs = {}
    tweets = train_data[['tweet']]
    for row_index,row in tweets.iterrows():
        s = row['tweet'].split()
        tot = 0.
        for word in s:
            if "http://" in word: continue #ignore hyperlinks
            tot += len(word)
        wcs[' '.join(s)] = tot / len(s)
    return wcs

# %%
#Gets the count of '@'s in the data
def get_at_counts():
    ats = {}
    tweets = train_data[['tweet']]
    for row_index,row in tweets.iterrows():
        s = row['tweet'].split()
        count = sum(map(lambda word : 1 if '@' in word else 0, s))
        ats[' '.join(s)] = count
            
    return ats

# %%
#Gets the count of swear words in tweets
#potentially use regex's to catch purposeful mispellings & other nuances
def get_swear_counts():
    tweets = train_data[['tweet']]
#     bad_word_list = open("en_bad_words.txt").read().replace("\n", "").split(',')
#     for i in range(len(bad_word_list)):
#         bad_word_list[i] = bad_word_list[i].strip(" ")
    bad_words_set = set(open("bad-words.txt").read().split())
    
    bad_words_count = {}
    for row_index,row in tweets.iterrows():
        s = row['tweet'].split()
        tot_bad = 0
        for word in s:                #Use regexs? 
            word = word.replace(".","").replace(",","").replace("!","").replace("?","")
            if word.lower() in bad_words_set:
                tot_bad+=1
            bad_words_count[" ".join(s)] = tot_bad
            
    return bad_words_count

# %%
#unigram_counts = get_unigrams_splitBySpace()
uni_tokenizer_counts = get_unigrams_nltkTokenizer()
#bigram_counts = get_bigrams()
#avg_wc = get_avg_wc()
#at_counts = get_at_counts()
#swear_counts = get_swear_counts()

# %%
#get top 100 unigrams and bigrams
top_unigrams = unigram_counts.most_common(100)
top_tokenized = uni_tokenizer_counts.most_common(100)
print(top_tokenized)
top_bigrams = bigram_counts.most_common(100)
data = pd.concat([train_data, dev_data])
#print(type(top_unigrams), type(top_tokenized))
# Out:
# [(':', 8187), ('.', 8001), ('a', 7274), ('bitch', 6518), ('RT', 6081), ('I', 5428), ('the', 5285), (',', 4842), ('to', 4217), ('you', 4212), ('"', 4118), ('!', 3190), ('and', 2949), ('that', 2550), ('my', 2482), ('in', 2410), ('bitches', 2368), ('is', 2241), ('😂', 2219), ('like', 2112), ('me', 2096), ('?', 2016), ('of', 1994), ('on', 1919), ('be', 1896), ('hoes', 1835), ('pussy', 1678), ('for', 1675), ('...', 1674), ('hoe', 1531), ('with', 1473), ('it', 1431), ('“', 1370), ('this', 1291), ('”', 1288), ("I'm", 1264), ('ass', 1235), ('up', 1204), ('your', 1112), ('get', 1064), ('but', 1034), ("don't", 1019), ('all', 1007), ('just', 1002), ('got', 951), ('they', 947), ('shit', 947), ('fuck', 933), ('u', 926), ('trash', 923), ('her', 914), ('was', 906), ('are', 903), ('so', 897), ('nigga', 891), ('…', 881), ('..', 853), ('no', 851), ('at', 845), ('out', 845), ('not', 827), ('these', 812), ('have', 777), ('she', 776), ('when', 773), ('&', 750), ('about', 729), ('i', 724), ('if', 702), ("ain't", 689), ('You', 642), ('lol', 633), ('know', 626), ('he', 608), ('do', 603), ('some', 600), ('can', 585), ('them', 536), ('or', 524), ('what', 524), ('one', 518), ('love', 517), ('niggas', 508), ('If', 496), ('as', 495), ("'", 485), ('fucking', 473), ('go', 467), ('we', 466), ('who', 464), ('-', 441), ('from', 437), ('want', 434), ('how', 428), ('yo', 425), ('then', 421), ('bad', 416), ('The', 410), ('his', 403), ('now', 402)]

# %%
def process_tweets(tweets):
    for word in [u[0] for u in top_unigrams]:
        print("u is in unogram ",u)
        tweets[word] = tweets['tweet'].str.contains(word).astype(int)
        print(word)
    #print(tweets)
    word_counts = []
    swear_counts = []
    at_counts = []
    bad_words_set = set(open("bad-words.txt").read().split())

    for tweet in tweets['tweet']:
        tweet_words = tweet.split()
        word_counts.append(len(tweet_words))
        tot_bad = 0
        #print(tweet_words)
        for word in tweet_words:                #Use regexs? 
            word = word.replace(".","").replace(",","").replace("!","").replace("?","")
            if word.lower() in bad_words_set:
                tot_bad+=1
        swear_counts.append(tot_bad)
        at_count = tweet_words.count('@')
        at_counts.append(at_count)

    tweets['Word Counts'] = word_counts
    tweets['Swear Counts'] = swear_counts
    tweets['@ Counts'] = at_counts
    X = tweets[[col for col in tweets.columns if col!="tweet"]].values
    return X

# %%
def process_tokenized_tweets(tweets):
    print(tweets)
    for word in [u[0] for u in top_unigrams]:
        #print("u is ",u[0])
        #print(word)
        tweets[word] = tweets['tweet'].str.contains(word).astype(int)
        #print(tweets[word])
    '''word_counts = []
    swear_counts = []
    at_counts = []
    bad_words_set = set(open("bad-words.txt").read().split())

    for tweet in tweets['tweet']:
        tweet_words = tweet.split()
        word_counts.append(len(tweet))
        tot_bad = 0
        for word in tweet:                #Use regexs? 
            word = word.replace(".","").replace(",","").replace("!","").replace("?","")
            if word.lower() in bad_words_set:
                tot_bad+=1
        swear_counts.append(tot_bad)
        at_count = tweet.count('@')
        at_counts.append(at_count)

    tweets['Word Counts'] = word_counts
    tweets['Swear Counts'] = swear_counts
    tweets['@ Counts'] = at_counts
    X_tokenized = tweets[[col for col in tweets.columns if col!="tweet"]].values
    return X_tokenized'''

# %%
tweets = data[['tweet']]
#print(tweets)
#X = process_tweets(tweets)

X_tokenized = process_tokenized_tweets(tweets)
#print(type(X_tokenized))
y = data['class'].values
# Out:
#                                                    tweet
# 12549  Kim K is alright but honestly so many niggas b...
# 11681  I'm so mother fucken sexy. I have no time to b...
# 14791  RT @Booskerz: "@DailySexSupply: Girls that fuc...
# 22367  Think it's okay to take my property and break ...
# 8015   Apologizing in advance for my actions, I'm the...
# 21219  She used to fuck wit A$AP, Too Shortsaid he kn...
# 6091   @elise_palmer sounds like gypos to me - they u...
# 14302                   Quit blowing up my feed bitches.
# 24854  please tell this bitch I'm subbin her, ik one ...
# 24760  never lie \nnever cry\nnever die\nwe gone die\...
# 15031  RT @ChiefKeef: You niggaz get so emotionaaaal,...
# 935    #tbt when i took my likkle monkey jimmys http:...
# 4263   @MisterDimmadome \nspiked that bitch\ndamned n...
# 11501          I'm a pull up, eat on that pussy, and dip
# 17087  RT @NotWorldStar: When you drop all your hoes ...
# 19262  RT @danwashburn: The Man Who Captured Muammar ...
# 23571  Yall know Skip Bayless is about to slit his wr...
# 15035  RT @Chill__Nigga: I can't be in my twenties st...
# 5611               @_xxsarafina haha that hoe go hard rt
# 12533                               Kevin hart 4"8 bitch
# 971               &#128075; hi-ho http://t.co/FiC4FnRutZ
# 19723  RT @itskingdee: @1inkkofrosess fuck them hoes!...
# 4356   @NYRKelsMads @DaniloNavarro85 Hey fag, I said ...
# 17159  RT @OfficialKingDre: WTF did this bitch do? &#...
# 14922  RT @Cajun_peach: Because humans aren't delicio...
# 498    "I will fuck u where u stand". "U dizzy bitch"...
# 1440   &#8220;@MattieTrump97: Eat a lot of protein\nE...
# 9522   Fuck rebuild the tranny, I'm driving it like i...
# 12978  Lord please get me out of this ghetto ass hosp...
# 13467  My sister called the chinks an asked was they ...
# ...                                                  ...
# 24566  ik I look good and all but dam bitches stop ma...
# 1123   &#8220;@AlmightyCBoogie: @BenBornReadySMU @viv...
# 11445  I'd shut the fuck up or I'll just be wide and ...
# 13190                           Molly make bitches crazy
# 15505  RT @FREDOSANTANA300: I smashed her an dat puss...
# 24065  and if that's yo bitch then you may have to fi...
# 14696  RT @BestOfNike: Nike beanies #NikePorn http://...
# 14411  RT @AIanHangover: "what are you 15?"\n\nyeah o...
# 16809  RT @MiSSKathEVO: #NoFilter I been getting mone...
# 918    #porn,#android,#iphone,#ipad,#sex,#xxx, | #Old...
# 6354   @intrepidokie nice lie #teabagger. Just becaus...
# 4360   @NYRKelsMads Thanks for calling me a fucking fag.
# 22943  Walked into a party and they was playin Nelly ...
# 14199  Playing games and wrestling are the only ways ...
# 11353  I wasn't born last night, I know these hoes ai...
# 4654                 @ResiDinero we some hoes bruhhh lol
# 14997  RT @ChannyMaraj You prolly ate ur dad...he hat...
# 22178                These bitches are taking forevs doe
# 6156   @freshalina I call those my ghetto nunchucks.....
# 6794   @lvnzo oh hell no they act proper and i live i...
# 7511   @wodaeeex3 bitch i juss askd yu uh question yo...
# 20450  RT @shelbieperdue: Instagram needs to stop bei...
# 14821  RT @BrianFromWork: @ThatOneGirlPink @coL_TuQui...
# 12199  It is impossible for females to be players, pi...
# 9190   Embrace it. Love it. Flip this group of mine r...
# 14628  RT @BadAdviceDog: r u african because ur afric...
# 22746  Truth is @MaxOn_MaxOff5 ate yellow snow as a c...
# 13417  My nicca @Elijahfnbaby swear he can see me in ...
# 11017  I love when people bitch about athletes being ...
# 3475   @Honey_GotBunns bitch you know you won't this ...
#
# [22214 rows x 1 columns]
# u is  0
# a
# u is  0
# RT
# u is  0
# bitch
# u is  0
# the
# /Users/susanabenavidez/anaconda3/envs/nlu/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# u is  0
# I
# u is  0
# to
# u is  0
# you
# u is  0
# and
# u is  0
# my
# u is  0
# that
# u is  0
# in
# u is  0
# is
# u is  0
# like
# u is  0
# bitches
# u is  0
# of
# u is  0
# be
# u is  0
# on
# u is  0
# me
# u is  0
# for
# u is  0
# hoes
# u is  0
# with
# u is  0
# pussy
# u is  0
# this
# u is  0
# I'm
# u is  0
# hoe
# u is  0
# it
# u is  0
# ass
# u is  0
# your
# u is  0
# up
# u is  0
# get
# u is  0
# but
# u is  0
# don't
# u is  0
# just
# u is  0
# all
# u is  0
# got
# u is  0
# they
# u is  0
# was
# u is  0
# u
# u is  0
# so
# u is  0
# fuck
# u is  0
# are
# u is  0
# her
# u is  0
# at
# u is  0
# these
# u is  0
# no
# u is  0
# not
# u is  0
# out
# u is  0
# shit
# u is  0
# have
# u is  0
# nigga
# u is  0
# when
# u is  0
# she
# u is  0
# about
# u is  0
# trash
# u is  0
# i
# u is  0
# if
# u is  0
# ain't
# u is  0
# &amp;
# u is  0
# he
# u is  0
# know
# u is  0
# You
# u is  0
# some
# u is  0
# can
# u is  0
# do
# u is  0
# lol
# u is  0
# or
# u is  0
# love
# u is  0
# as
# u is  0
# If
# u is  0
# them
# u is  0
# one
# u is  0
# what
# u is  0
# fucking
# u is  0
# we
# u is  0
# niggas
# u is  0
# who
# u is  0
# go
# u is  0
# bitch.
# u is  0
# from
# u is  0
# how
# u is  0
# want
# u is  0
# yo
# u is  0
# his
# u is  0
# then
# u is  0
# The
# u is  0
# can't
# u is  0
# This
# u is  0
# bad
# u is  0
# make
# u is  0
# My
# u is  0
# think
# u is  0
# still
# u is  0
# say
# u is  0
# see
# u is  0
# it's
# u is  0
# need
# u is  0
# an
# u is  0
# will
# u is  0
# .
# u is  0
# ya

# %%
cv = KFold(n_splits=10, random_state=42, shuffle=False)
LR_scores = []
SVM_scores = []

for train_index, test_index in cv.split(X):
    LR = LogisticRegression(fit_intercept=True, max_iter=1000, solver='lbfgs', multi_class='ovr')
    svm = SVC(gamma='auto') 
    X_train, X_test, y_train, y_test = X[train_index], X[test_index], y[train_index], y[test_index]
    LR.fit(X_train, y_train)
    LR_scores.append(LR.score(X_test, y_test))
    svm.fit(X_train, y_train)
    SVM_scores.append(svm.score(X_test, y_test))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-228-ef02b625ddb9> in <module>
#       9     LR.fit(X_train, y_train)
#      10     LR_scores.append(LR.score(X_test, y_test))
# ---> 11     svm.fit(X_train, y_train)
#      12     SVM_scores.append(svm.score(X_test, y_test))
#      13
#
# ~/anaconda3/envs/nlu/lib/python3.7/site-packages/sklearn/svm/base.py in fit(self, X, y, sample_weight)
#     210
#     211         seed = rnd.randint(np.iinfo('i').max)
# --> 212         fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     213         # see comment on the other call to np.iinfo in this file
#     214
#
# ~/anaconda3/envs/nlu/lib/python3.7/site-packages/sklearn/svm/base.py in _dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     269                 cache_size=self.cache_size, coef0=self.coef0,
#     270                 gamma=self._gamma, epsilon=self.epsilon,
# --> 271                 max_iter=self.max_iter, random_seed=random_seed)
#     272
#     273         self._warn_from_fit_status()
#
# KeyboardInterrupt:

# %%
LR_scores
# Out:
# [0.8618361836183618,
#  0.8550855085508551,
#  0.8672367236723673,
#  0.8861386138613861,
#  0.8716794236830256,
#  0.875281404772625,
#  0.8779828905898244,
#  0.8928410625844214,
#  0.8829356145880234,
#  0.8793336334984241]

# %%
SVM_scores
# Out:
# [0.8604860486048604,
#  0.8577857785778578,
#  0.864986498649865,
#  0.8771377137713772,
#  0.8680774425934263,
#  0.8671769473210266,
#  0.8766321476812247,
#  0.884736605132823,
#  0.8757316524088249,
#  0.8833858622242233]
